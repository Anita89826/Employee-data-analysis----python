# %% [markdown]
# # Data Cleaning

# %%
import pandas

# %%
data = pandas.read_excel('Data 101 YT.xlsx','Conditional formatting')

# %%
data
# Out:
#            Unnamed: 0 Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 0                 NaN        NaN                   NaN        NaN
# 1                 NaN        NaN                   NaN        NaN
# 2                 NaN        NaN                   NaN        NaN
# 3       Employee Name   Building            Department     Status
# 4          Page, Lisa       West                   ADC  Full Time
# ..                ...        ...                   ...        ...
# 740       Olsen, Ewan      North  Research/Development   Contract
# 741        Green, Kim     Watson  Research/Development  Half-Time
# 742  Bradshaw, Sheryl      North  Research/Development   Contract
# 743      Riley, David       Taft  Research/Development  Full Time
# 744    Flynn, Melissa     Watson  Research/Development     Hourly
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN         NaN
# ...

# %%
data.head(20)
# Out:
#             Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3           Unnamed: 4  \
# 0                  NaN        NaN         NaN        NaN                  NaN
# 1                  NaN        NaN         NaN        NaN                  NaN
# 2                  NaN        NaN         NaN        NaN                  NaN
# 3        Employee Name   Building  Department     Status            Hire Date
# 4           Page, Lisa       West         ADC  Full Time  1999-01-11 00:00:00
# 5       Taylor, Hector       West         ADC  Half-Time  2011-02-21 00:00:00
# 6     Dawson, Jonathan       West         ADC   Contract  2007-03-06 00:00:00
# 7         Duran, Brian       Taft         ADC     Hourly  2012-08-30 00:00:00
# 8         Weber, Larry     Watson         ADC  Full Time  2007-12-31 00:00:00
# 9          Pratt, Erik      North    Training  Full Time  2006-02-03 00:00:00
# 10      O'Connor, Kent       Taft    Training  Half-Time  1999-02-26 00:00:00
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of            Unnamed: 0 Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 0                 NaN        NaN                   NaN        NaN
# 1                 NaN        NaN                   NaN        NaN
# 2                 NaN        NaN                   NaN        NaN
# 3       Employee Name   Building            Department     Status
# 4          Page, Lisa       West                   ADC  Full Time
# ..                ...        ...                   ...        ...
# 740       Olsen, Ewan      North  Research/Development   Contract
# 741        Green, Kim     Watson  Research/Development  Half-Time
# 742  Bradshaw, Sheryl      North  Research/Development   Contract
# 743      Riley, David       Taft  Research/Development  Full Time
# 744    Flynn, Melissa     Watson  Research/Development     Hourly
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0                    NaN        NaN        NaN        NaN         NaN
# ...

# %% [markdown]
# ###### Data Cleaning

# %%
data.head()
# Out:
#       Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3           Unnamed: 4  \
# 0            NaN        NaN         NaN        NaN                  NaN
# 1            NaN        NaN         NaN        NaN                  NaN
# 2            NaN        NaN         NaN        NaN                  NaN
# 3  Employee Name   Building  Department     Status            Hire Date
# 4     Page, Lisa       West         ADC  Full Time  1999-01-11 00:00:00
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# 0        NaN        NaN        NaN         NaN         NaN          NaN
# 1        NaN        NaN        NaN         NaN         NaN          NaN
# 2        NaN        NaN        NaN         NaN         NaN          NaN
# 3      Years   Benefits     Salary  Job Rating  New Salary          NaN
# 4         20        DMR      54550           1   55864.655          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# ...

# %%
###### taking off the first 3 rows
data.drop([0,1,2], inplace = True)

# %%
data.index 
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
data.drop(['Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18'],axis=1,inplace=True)

# %%
data
# Out:
#            Unnamed: 0 Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 3       Employee Name   Building            Department     Status
# 4          Page, Lisa       West                   ADC  Full Time
# 5      Taylor, Hector       West                   ADC  Half-Time
# 6    Dawson, Jonathan       West                   ADC   Contract
# 7        Duran, Brian       Taft                   ADC     Hourly
# ..                ...        ...                   ...        ...
# 740       Olsen, Ewan      North  Research/Development   Contract
# 741        Green, Kim     Watson  Research/Development  Half-Time
# 742  Bradshaw, Sheryl      North  Research/Development   Contract
# 743      Riley, David       Taft  Research/Development  Full Time
# 744    Flynn, Melissa     Watson  Research/Development     Hourly
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 3              Hire Date      Years   Benefits     Salary  Job Rating
# ...

# %% [markdown]
# ### Get 741

# %%
data.loc[741]
# Out:
# Unnamed: 0              Green, Kim
# Unnamed: 1                  Watson
# Unnamed: 2    Research/Development
# Unnamed: 3               Half-Time
# Unnamed: 4     2000-02-01 00:00:00
# Unnamed: 5                      19
# Unnamed: 6                     DMR
# Unnamed: 7                   31250
# Unnamed: 8                       2
# Unnamed: 9                   31250
# Name: 741, dtype: object

# %% [markdown]
# ### Get page Lisa  recoed

# %%
data.loc[4]
# Out:
# Unnamed: 0             Page, Lisa
# Unnamed: 1                   West
# Unnamed: 2                    ADC
# Unnamed: 3              Full Time
# Unnamed: 4    1999-01-11 00:00:00
# Unnamed: 5                     20
# Unnamed: 6                    DMR
# Unnamed: 7                  54550
# Unnamed: 8                      1
# Unnamed: 9              55864.655
# Name: 4, dtype: object

# %% [markdown]
# ### Get 20 - 30 Row

# %%
data.loc[20:30]
# Out:
#             Unnamed: 0 Unnamed: 1                Unnamed: 2 Unnamed: 3  \
# 20           Rowe, Ken       West                  Training   Contract
# 21         Burton, Cam       West                  Training  Full Time
# 22     Phillips, Liesl      South                  Training  Full Time
# 23  Gallagher, Johnson       West                  Training     Hourly
# 24        Wolf, Debbie       Taft                  Training  Full Time
# 25        Todd, Steven     Watson                  Training  Full Time
# 26  McKenzie, Michelle       Main  Environmental Compliance  Full Time
# 27   Thornton, Charles       West  Environmental Compliance  Full Time
# 28       Dunn, Matthew      North  Environmental Compliance  Full Time
# 29        Potter, Dawn       Taft  Environmental Compliance  Full Time
# 30       Carroll, Lesa       West  Environmental Compliance  Full Time
#
#              Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data['Unnamed: 9']
# Out:
# 3      New Salary
# 4       55864.655
# 5           26795
# 6           42540
# 7           35680
#           ...
# 740         60760
# 741         31250
# 742         64720
# 743         46680
# 744         19044
# Name: Unnamed: 9, Length: 742, dtype: object

# %%
data
# Out:
#            Unnamed: 0 Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 3       Employee Name   Building            Department     Status
# 4          Page, Lisa       West                   ADC  Full Time
# 5      Taylor, Hector       West                   ADC  Half-Time
# 6    Dawson, Jonathan       West                   ADC   Contract
# 7        Duran, Brian       Taft                   ADC     Hourly
# ..                ...        ...                   ...        ...
# 740       Olsen, Ewan      North  Research/Development   Contract
# 741        Green, Kim     Watson  Research/Development  Half-Time
# 742  Bradshaw, Sheryl      North  Research/Development   Contract
# 743      Riley, David       Taft  Research/Development  Full Time
# 744    Flynn, Melissa     Watson  Research/Development     Hourly
#
#               Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 3              Hire Date      Years   Benefits     Salary  Job Rating
# ...

# %%
data.loc[3]
# Out:
# Unnamed: 0    Employee Name
# Unnamed: 1         Building
# Unnamed: 2       Department
# Unnamed: 3           Status
# Unnamed: 4        Hire Date
# Unnamed: 5            Years
# Unnamed: 6         Benefits
# Unnamed: 7           Salary
# Unnamed: 8       Job Rating
# Unnamed: 9       New Salary
# Name: 3, dtype: object

# %% [markdown]
# ## use column 3 as a heading

# %%
data.columns = data.loc[3]

# %%
data.drop(3,inplace=True)

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  \
# 4          Page, Lisa     West                   ADC  Full Time
# 5      Taylor, Hector     West                   ADC  Half-Time
# 6    Dawson, Jonathan     West                   ADC   Contract
# 7        Duran, Brian     Taft                   ADC     Hourly
# 8        Weber, Larry   Watson                   ADC  Full Time
# ..                ...      ...                   ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract
# 741        Green, Kim   Watson  Research/Development  Half-Time
# 742  Bradshaw, Sheryl    North  Research/Development   Contract
# 743      Riley, David     Taft  Research/Development  Full Time
# 744    Flynn, Melissa   Watson  Research/Development     Hourly
#
# 3              Hire Date Years Benefits Salary Job Rating New Salary
# 4    1999-01-11 00:00:00    20      DMR  54550          1  55864.655
# ...

# %% [markdown]
# # Column Data Type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee Name  741 non-null    object
#  1   Building       741 non-null    object
#  2   Department     741 non-null    object
#  3   Status         741 non-null    object
#  4   Hire Date      741 non-null    object
#  5   Years          741 non-null    object
#  6   Benefits       494 non-null    object
#  7   Salary         741 non-null    object
#  8   Job Rating     741 non-null    object
#  9   New Salary     741 non-null    object
# dtypes: object(10)
# memory usage: 58.0+ KB

# %% [markdown]
# # Data type Conversion

# %%
data['Salary']
# Out:
# 4      54550
# 5      26795
# 6      42540
# 7      35680
# 8      72830
#        ...
# 740    60760
# 741    31250
# 742    64720
# 743    46680
# 744    19044
# Name: Salary, Length: 741, dtype: object

# %%
data['Salary'].astype(int)
# Out:
# 4      54550
# 5      26795
# 6      42540
# 7      35680
# 8      72830
#        ...
# 740    60760
# 741    31250
# 742    64720
# 743    46680
# 744    19044
# Name: Salary, Length: 741, dtype: int32

# %%
data['Salary']=data['Salary'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee Name  741 non-null    object
#  1   Building       741 non-null    object
#  2   Department     741 non-null    object
#  3   Status         741 non-null    object
#  4   Hire Date      741 non-null    object
#  5   Years          741 non-null    object
#  6   Benefits       494 non-null    object
#  7   Salary         741 non-null    int32
#  8   Job Rating     741 non-null    object
#  9   New Salary     741 non-null    object
# dtypes: int32(1), object(9)
# memory usage: 55.1+ KB

# %%
data[['Years','Job Rating','New Salary']].astype(int)
# Out:
# 3    Years  Job Rating  New Salary
# 4       20           1       55864
# 5        8           4       26795
# 6       12           5       42540
# 7        7           2       35680
# 8       11           2       72830
# ..     ...         ...         ...
# 740     12           2       60760
# 741     19           2       31250
# 742     11           5       64720
# 743      9           1       46680
# 744      8           1       19044
#
# [741 rows x 3 columns]

# %%
data[['Years','Job Rating','New Salary']]=data[['Years','Job Rating','New Salary']].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee Name  741 non-null    object
#  1   Building       741 non-null    object
#  2   Department     741 non-null    object
#  3   Status         741 non-null    object
#  4   Hire Date      741 non-null    object
#  5   Years          741 non-null    int32
#  6   Benefits       494 non-null    object
#  7   Salary         741 non-null    int32
#  8   Job Rating     741 non-null    int32
#  9   New Salary     741 non-null    int32
# dtypes: int32(4), object(6)
# memory usage: 46.4+ KB

# %% [markdown]
# ## Date Counversion

# %%
pandas.to_datetime(data['Hire Date'])
# Out:
# 4     1999-01-11
# 5     2011-02-21
# 6     2007-03-06
# 7     2012-08-30
# 8     2007-12-31
#          ...
# 740   2007-02-03
# 741   2000-02-01
# 742   2008-07-10
# 743   2010-07-25
# 744   2010-12-31
# Name: Hire Date, Length: 741, dtype: datetime64[ns]

# %%
data['Hire Date'] = pandas.to_datetime(data['Hire Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee Name  741 non-null    object
#  1   Building       741 non-null    object
#  2   Department     741 non-null    object
#  3   Status         741 non-null    object
#  4   Hire Date      741 non-null    datetime64[ns]
#  5   Years          741 non-null    int32
#  6   Benefits       494 non-null    object
#  7   Salary         741 non-null    int32
#  8   Job Rating     741 non-null    int32
#  9   New Salary     741 non-null    int32
# dtypes: datetime64[ns](1), int32(4), object(5)
# memory usage: 46.4+ KB

# %% [markdown]
# # Select a particular data type

# %%
data.select_dtypes(include=object)
# Out:
# 3       Employee Name Building            Department     Status Benefits
# 4          Page, Lisa     West                   ADC  Full Time      DMR
# 5      Taylor, Hector     West                   ADC  Half-Time       DM
# 6    Dawson, Jonathan     West                   ADC   Contract      NaN
# 7        Duran, Brian     Taft                   ADC     Hourly      NaN
# 8        Weber, Larry   Watson                   ADC  Full Time        M
# ..                ...      ...                   ...        ...      ...
# 740       Olsen, Ewan    North  Research/Development   Contract      NaN
# 741        Green, Kim   Watson  Research/Development  Half-Time      DMR
# 742  Bradshaw, Sheryl    North  Research/Development   Contract      NaN
# 743      Riley, David     Taft  Research/Development  Full Time      DMR
# 744    Flynn, Melissa   Watson  Research/Development     Hourly      NaN
#
# [741 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741 entries, 4 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee Name  741 non-null    object
#  1   Building       741 non-null    object
#  2   Department     741 non-null    object
#  3   Status         741 non-null    object
#  4   Hire Date      741 non-null    datetime64[ns]
#  5   Years          741 non-null    int32
#  6   Benefits       494 non-null    object
#  7   Salary         741 non-null    int32
#  8   Job Rating     741 non-null    int32
#  9   New Salary     741 non-null    int32
# dtypes: datetime64[ns](1), int32(4), object(5)
# memory usage: 46.4+ KB

# %% [markdown]
# ### To check distinct rows Values

# %%
data['Benefits'].unique()
# Out:
# array(['DMR', 'DM', nan, 'M', 'D', 'R', 'DR'], dtype=object)

# %%
data['Status'].unique
# Out:
# <bound method Series.unique of 4      Full Time
# 5      Half-Time
# 6       Contract
# 7         Hourly
# 8      Full Time
#          ...
# 740     Contract
# 741    Half-Time
# 742     Contract
# 743    Full Time
# 744       Hourly
# Name: Status, Length: 741, dtype: object>

# %% [markdown]
# ### To see all the valus on the value

# %%
data['Status'].values
# Out:
# array(['Full Time', 'Half-Time', 'Contract', 'Hourly', 'Full Time',
#        'Full Time', 'Half-Time', 'Contract', 'Full Time', 'Full Time',
#        'Half-Time', 'Full Time', 'Half-Time', 'Full Time', 'Full Time',
#        'Hourly', 'Contract', 'Full Time', 'Full Time', 'Hourly',
#        'Full Time', 'Full Time', 'Full Time', 'Full Time', 'Full Time',
#        'Full Time', 'Full Time', 'Half-Time', 'Hourly', 'Full Time',
#        'Full Time', 'Full Time', 'Full Time', 'Contract', 'Half-Time',
#        'Half-Time', 'Hourly', 'Contract', 'Full Time', 'Half-Time',
#        'Contract', 'Full Time', 'Half-Time', 'Contract', 'Full Time',
#        'Full Time', 'Contract', 'Contract', 'Half-Time', 'Hourly',
#        'Full Time', 'Contract', 'Contract', 'Full Time', 'Full Time',
#        'Contract', 'Full Time', 'Full Time', 'Full Time', 'Full Time',
#        'Full Time', 'Full Time', 'Full Time', 'Contract', 'Contract',
# ...

# %% [markdown]
# ### To replace a specific column

# %%
data['Benefits'].fillna('No Benefits')
# Out:
# 4              DMR
# 5               DM
# 6      No Benefits
# 7      No Benefits
# 8                M
#           ...
# 740    No Benefits
# 741            DMR
# 742    No Benefits
# 743            DMR
# 744    No Benefits
# Name: Benefits, Length: 741, dtype: object

# %% [markdown]
# ### fikkna is to remove non value or NA

# %% [markdown]
# ### To replace with name of the column eg, data['Benefits']

# %%
data['Benefits'] = data['Benefits'].fillna('No Benefits')

# %% [markdown]
# ### To see the effect

# %%
data['Benefits']
# Out:
# 4              DMR
# 5               DM
# 6      No Benefits
# 7      No Benefits
# 8                M
#           ...
# 740    No Benefits
# 741            DMR
# 742    No Benefits
# 743            DMR
# 744    No Benefits
# Name: Benefits, Length: 741, dtype: object

# %% [markdown]
# ### you call out your data

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4          Page, Lisa     West                   ADC  Full Time 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC  Full Time 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development  Full Time 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ### to replace value that is not NA

# %%
data.replace('Page, Lisa','Othello')
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC  Full Time 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC  Full Time 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development  Full Time 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ### To make permanent with inplace = True

# %%
data.replace('Page, Lisa','Othello',inplace=True)

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC  Full Time 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC  Full Time 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development  Full Time 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ### toveiw the coumn satus

# %%
data['Status']
# Out:
# 4      Full Time
# 5      Half-Time
# 6       Contract
# 7         Hourly
# 8      Full Time
#          ...
# 740     Contract
# 741    Half-Time
# 742     Contract
# 743    Full Time
# 744       Hourly
# Name: Status, Length: 741, dtype: object

# %% [markdown]
# ### To replace ( Full Time to F T)

# %%
data['Status'].replace('Full Time','F T')
# Out:
# 4            F T
# 5      Half-Time
# 6       Contract
# 7         Hourly
# 8            F T
#          ...
# 740     Contract
# 741    Half-Time
# 742     Contract
# 743          F T
# 744       Hourly
# Name: Status, Length: 741, dtype: object

# %%
data['Status'].replace('Full Time','F T',inplace=True)
# or data['Status'] = data['Status'].replace('Full Time')

# %% [markdown]
# ### i call my Table to see change

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC        F T 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC        F T 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development        F T 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ### To work on table year, veiw frist

# %%
data['Years']
# Out:
# 4      20
# 5       8
# 6      12
# 7       7
# 8      11
#        ..
# 740    12
# 741    19
# 742    11
# 743     9
# 744     8
# Name: Years, Length: 741, dtype: int32

# %% [markdown]
# ### To replace the number with another number eg 12 to 14

# %% [markdown]
# data['Years'].replace(12,14)

# %% [markdown]
# ### to make permanent with inplace=True

# %%
data['Years'].replace(12,14,inplace=True)

# %% [markdown]
# ### view the table

# %%
data['Years']
# Out:
# 4      20
# 5       8
# 6      14
# 7       7
# 8      11
#        ..
# 740    14
# 741    19
# 742    11
# 743     9
# 744     8
# Name: Years, Length: 741, dtype: int32

# %% [markdown]
# ### call the Table

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC        F T 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC        F T 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development        F T 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC        F T 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC        F T 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development        F T 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ## Sorting and filtering

# %%
my_copy = data.copy()

# %%
my_copy.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary
# 4          DMR   54550           1       55864
# 5           DM   26795           4       26795
# 6  No Benefits   42540           5       42540
# 7  No Benefits   35680           2       35680
# 8            M   72830           2       72830

# %% [markdown]
# ## sorting

# %%
my_copy.sort_values('Salary',ascending=False)
# Out:
# 3         Employee Name Building                   Department     Status  \
# 178          Tran, Chad     Main           Major Mfg Projects  Half-Time
# 251     Burgess, Cherie    North                Manufacturing        F T
# 541       Cameron, John    North           Account Management   Contract
# 284    Huffman, Ignacio    North                Manufacturing   Contract
# 579     Alvarez, Steven     Taft            Quality Assurance   Contract
# ..                  ...      ...                          ...        ...
# 109       Carey, Andrea    North  Environmental Health/Safety  Half-Time
# 254       Hurst, Thomas     Main                Manufacturing     Hourly
# 456         Hines, Herb     Main                           IT     Hourly
# 278       Atkins, Kevin    North                Manufacturing     Hourly
# 237  Dickerson, Lincoln    North                Manufacturing     Hourly
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary
# ...

# %%
my_copy.sort_values('Years',ascending=True)
# Out:
# 3         Employee Name Building              Department     Status  \
# 726       Garcia, Karen     Main         Quality Control        F T
# 439      Walsh, Matthew    North                      IT   Contract
# 699       Snyder, Duane     West         Quality Control   Contract
# 40        Bullock, Greg    North  Facilities/Engineering     Hourly
# 487  Fitzgerald, George     West      Account Management   Contract
# ..                  ...      ...                     ...        ...
# 86   Perry, Christopher     West  Facilities/Engineering   Contract
# 191       Tate, Zachary     Taft           Manufacturing        F T
# 599        Henry, Craig    North       Quality Assurance        F T
# 298          Pena, Erik    South           Manufacturing     Hourly
# 192      Baxter, Teresa     Taft           Manufacturing  Half-Time
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary
# 726 2012-12-19      6           DM   59490           3       59490
# ...

# %%
my_copy.sort_values(['Job Rating', 'Years', 'Employee Name'], ascending=False)
# Out:
# 3        Employee Name Building              Department    Status  Hire Date  \
# 24        Wolf, Debbie     Taft                Training       F T 1998-12-14
# 68    Wallace, Timothy   Watson  Facilities/Engineering  Contract 1998-05-25
# 207       Walker, Mike   Watson           Manufacturing       F T 1998-02-04
# 593        Turner, Ray     West       Quality Assurance    Hourly 1998-03-15
# 714    Thomas, Shannon     Taft         Quality Control       F T 1998-10-12
# ..                 ...      ...                     ...       ...        ...
# 50         Pitts, Dana     Taft  Facilities/Engineering  Contract 2012-03-15
# 226  Greene, Alexander     West           Manufacturing       F T 2012-04-26
# 570      Fisher, Maria    North       Quality Assurance       F T 2012-01-01
# 369   Buckel, Patricia     Taft               Marketing       F T 2012-06-10
# 409         Ball, Kirk    North                   Sales       F T 2012-10-27
#
# ...

# %% [markdown]
# ## Filtering

# %%
my_copy.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary
# 4          DMR   54550           1       55864
# 5           DM   26795           4       26795
# 6  No Benefits   42540           5       42540
# 7  No Benefits   35680           2       35680
# 8            M   72830           2       72830

# %%
my_copy['Job Rating'] == 5
# Out:
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
#        ...
# 740    False
# 741    False
# 742     True
# 743    False
# 744    False
# Name: Job Rating, Length: 741, dtype: bool

# %%
my_copy[my_copy['Job Rating'] == 5]
# Out:
# 3       Employee Name Building            Department    Status  Hire Date  \
# 6    Dawson, Jonathan     West                   ADC  Contract 2007-03-06
# 11      Spencer, Boyd     Main              Training  Contract 2007-04-17
# 17     Wilkins, Jesse    North              Training       F T 2012-08-15
# 21        Burton, Cam     West              Training       F T 2008-09-13
# 24       Wolf, Debbie     Taft              Training       F T 1998-12-14
# ..                ...      ...                   ...       ...        ...
# 728  Sweeney, Barbara    North       Quality Control       F T 2007-12-19
# 735    Bailey, Victor   Watson       Research Center       F T 2003-03-04
# 736     Montoya, Lisa     Main       Research Center       F T 2001-04-10
# 739    Leblanc, Jenny     West       Research Center       F T 2001-07-01
# 742  Bradshaw, Sheryl    North  Research/Development  Contract 2008-07-10
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %%
five = my_copy['Job Rating'] == 5

# %%
my_copy[five]
# Out:
# 3       Employee Name Building            Department    Status  Hire Date  \
# 6    Dawson, Jonathan     West                   ADC  Contract 2007-03-06
# 11      Spencer, Boyd     Main              Training  Contract 2007-04-17
# 17     Wilkins, Jesse    North              Training       F T 2012-08-15
# 21        Burton, Cam     West              Training       F T 2008-09-13
# 24       Wolf, Debbie     Taft              Training       F T 1998-12-14
# ..                ...      ...                   ...       ...        ...
# 728  Sweeney, Barbara    North       Quality Control       F T 2007-12-19
# 735    Bailey, Victor   Watson       Research Center       F T 2003-03-04
# 736     Montoya, Lisa     Main       Research Center       F T 2001-04-10
# 739    Leblanc, Jenny     West       Research Center       F T 2001-07-01
# 742  Bradshaw, Sheryl    North  Research/Development  Contract 2008-07-10
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ## Employee name that has e

# %%
my_copy['Employee Name'].str.contains('e')
# Out:
# 4       True
# 5       True
# 6      False
# 7      False
# 8       True
#        ...
# 740     True
# 741     True
# 742     True
# 743     True
# 744     True
# Name: Employee Name, Length: 741, dtype: bool

# %% [markdown]
# ## Employee Name taht has e

# %%
my_copy[my_copy['Employee Name'].str.contains('e') ]
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC        F T 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 8        Weber, Larry   Watson                   ADC        F T 2007-12-31
# 10     O'Connor, Kent     Taft              Training  Half-Time 1999-02-26
# 11      Spencer, Boyd     Main              Training   Contract 2007-04-17
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development        F T 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ## Employee Name Starting with B

# %%
b = my_copy['Employee Name'].str.startswith('B')
my_copy[b]
# Out:
# 3       Employee Name Building                Department     Status  \
# 16       Brewer, Kent     Main                  Training  Half-Time
# 21        Burton, Cam     West                  Training        F T
# 33      Blair, Sperry     West  Environmental Compliance        F T
# 36        Beck, Craig    North  Environmental Compliance        F T
# 38         Bond, John    North  Environmental Compliance  Half-Time
# ..                ...      ...                       ...        ...
# 689  Buchanan, Dennis    North           Quality Control   Contract
# 690     Brown, Donald    North           Quality Control     Hourly
# 701      Beard, Sandi   Watson           Quality Control  Half-Time
# 735    Bailey, Victor   Watson           Research Center        F T
# 742  Bradshaw, Sheryl    North      Research/Development   Contract
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary
# 16  2011-08-24      8           DM   30445           1       30445
# ...

# %% [markdown]
# ## OR

# %%
my_copy['Job Rating'] == 5
my_copy['Job Rating'] == 3
# Out:
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
#        ...
# 740    False
# 741    False
# 742    False
# 743    False
# 744    False
# Name: Job Rating, Length: 741, dtype: bool

# %% [markdown]
# ## OR

# %%
my_copy['Job Rating'] == 5 # 5jb
my_copy['Job Rating'] == 3 # 3jb

my_copy[(my_copy['Job Rating'] == 5) | (my_copy['Job Rating'] == 3)]
# Out:
# 3         Employee Name Building            Department     Status  Hire Date  \
# 6      Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 11        Spencer, Boyd     Main              Training   Contract 2007-04-17
# 14   Strickland, Rajean     Main              Training  Half-Time 2003-06-10
# 17       Wilkins, Jesse    North              Training        F T 2012-08-15
# 19      Holland, Donald    South              Training     Hourly 2011-09-01
# ..                  ...      ...                   ...        ...        ...
# 728    Sweeney, Barbara    North       Quality Control        F T 2007-12-19
# 735      Bailey, Victor   Watson       Research Center        F T 2003-03-04
# 736       Montoya, Lisa     Main       Research Center        F T 2001-04-10
# 739      Leblanc, Jenny     West       Research Center        F T 2001-07-01
# 742    Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
#
# ...

# %% [markdown]
# ## OR

# %%
my_copy['Job Rating'] == 5 # 5 jb
my_copy['Job Rating'] == 3 # 3 jb
# Out:
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
#        ...
# 740    False
# 741    False
# 742    False
# 743    False
# 744    False
# Name: Job Rating, Length: 741, dtype: bool

# %%
five_three = my_copy[(my_copy['Job Rating'] == 5) | (my_copy['Job Rating'] == 3)]

# %%
five_three
# Out:
# 3         Employee Name Building            Department     Status  Hire Date  \
# 6      Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 11        Spencer, Boyd     Main              Training   Contract 2007-04-17
# 14   Strickland, Rajean     Main              Training  Half-Time 2003-06-10
# 17       Wilkins, Jesse    North              Training        F T 2012-08-15
# 19      Holland, Donald    South              Training     Hourly 2011-09-01
# ..                  ...      ...                   ...        ...        ...
# 728    Sweeney, Barbara    North       Quality Control        F T 2007-12-19
# 735      Bailey, Victor   Watson       Research Center        F T 2003-03-04
# 736       Montoya, Lisa     Main       Research Center        F T 2001-04-10
# 739      Leblanc, Jenny     West       Research Center        F T 2001-07-01
# 742    Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
#
# ...

# %% [markdown]
# ## contract &

# %%
my_copy['Status'] == 'Contract' # contract
my_copy[ (my_copy['Job Rating'] == 5) & (my_copy['Status'] == 'Contract')]
# Out:
# 3           Employee Name Building              Department    Status  \
# 6        Dawson, Jonathan     West                     ADC  Contract
# 11          Spencer, Boyd     Main                Training  Contract
# 47          Briggs, Bryan     Main  Facilities/Engineering  Contract
# 51          Pruitt, Randy     Main  Facilities/Engineering  Contract
# 68       Wallace, Timothy   Watson  Facilities/Engineering  Contract
# 70       Morgan, Patricia    North  Facilities/Engineering  Contract
# 75           Stone, Brian    North  Facilities/Engineering  Contract
# 102      Stokes, Jonathan    North          Green Building  Contract
# 119         Maxwell, Jill     Taft                Creative  Contract
# 142          Bass, Justin    North     Product Development  Contract
# 147       Hardy, Svetlana     West     Product Development  Contract
# 157        Gallegos, Rick     Main     Product Development  Contract
# 166             Wise, Ted    North     Product Development  Contract
# ...

# %% [markdown]
# ## AND

# %%
my_copy['Job Rating'] == 5 # 5 jb
my_copy['Status'] == 'Contract' # contract
# Out:
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
#        ...
# 740     True
# 741    False
# 742     True
# 743    False
# 744    False
# Name: Status, Length: 741, dtype: bool

# %%
my_copy['Job Rating'] == 5 # 5 jb
my_copy['Status'] == 'Contract' # contract

my_copy[ (my_copy['Job Rating'] == 5) & (my_copy['Status'] == 'Contract')]
# Out:
# 3           Employee Name Building              Department    Status  \
# 6        Dawson, Jonathan     West                     ADC  Contract
# 11          Spencer, Boyd     Main                Training  Contract
# 47          Briggs, Bryan     Main  Facilities/Engineering  Contract
# 51          Pruitt, Randy     Main  Facilities/Engineering  Contract
# 68       Wallace, Timothy   Watson  Facilities/Engineering  Contract
# 70       Morgan, Patricia    North  Facilities/Engineering  Contract
# 75           Stone, Brian    North  Facilities/Engineering  Contract
# 102      Stokes, Jonathan    North          Green Building  Contract
# 119         Maxwell, Jill     Taft                Creative  Contract
# 142          Bass, Justin    North     Product Development  Contract
# 147       Hardy, Svetlana     West     Product Development  Contract
# 157        Gallegos, Rick     Main     Product Development  Contract
# 166             Wise, Ted    North     Product Development  Contract
# ...

# %% [markdown]
# ## AND

# %%
five = my_copy['Job Rating'] == 5 # jb
contract = my_copy['Status'] == 'Contract' # contract

my_copy[ (five) & (contract) ]
# Out:
# 3           Employee Name Building              Department    Status  \
# 6        Dawson, Jonathan     West                     ADC  Contract
# 11          Spencer, Boyd     Main                Training  Contract
# 47          Briggs, Bryan     Main  Facilities/Engineering  Contract
# 51          Pruitt, Randy     Main  Facilities/Engineering  Contract
# 68       Wallace, Timothy   Watson  Facilities/Engineering  Contract
# 70       Morgan, Patricia    North  Facilities/Engineering  Contract
# 75           Stone, Brian    North  Facilities/Engineering  Contract
# 102      Stokes, Jonathan    North          Green Building  Contract
# 119         Maxwell, Jill     Taft                Creative  Contract
# 142          Bass, Justin    North     Product Development  Contract
# 147       Hardy, Svetlana     West     Product Development  Contract
# 157        Gallegos, Rick     Main     Product Development  Contract
# 166             Wise, Ted    North     Product Development  Contract
# ...

# %% [markdown]
# ## Job rating of 5 or 3 and status of full time or contract

# %%
my_copy['Job Rating'] == 5 # jb
my_copy['Job Rating'] == 3 # jb
# Out:
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
#        ...
# 740    False
# 741    False
# 742    False
# 743    False
# 744    False
# Name: Job Rating, Length: 741, dtype: bool

# %%
my_copy['Status'] == 'Full Time'  # FT status
my_copy['Status'] == 'Contract' # Contract
# Out:
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
#        ...
# 740     True
# 741    False
# 742     True
# 743    False
# 744    False
# Name: Status, Length: 741, dtype: bool

# %%
five = my_copy['Job Rating'] == 5  # jb
three = my_copy['Job Rating'] == 3  # jb

Ft = my_copy['Status'] == 'Full Time' # FT
Contract = my_copy['Status'] == 'Contract' # Contract

my_copy[  (five | three) & (Ft | Contract)  ]
# Out:
# 3       Employee Name Building              Department    Status  Hire Date  \
# 6    Dawson, Jonathan     West                     ADC  Contract 2007-03-06
# 11      Spencer, Boyd     Main                Training  Contract 2007-04-17
# 20          Rowe, Ken     West                Training  Contract 2000-09-08
# 47      Briggs, Bryan     Main  Facilities/Engineering  Contract 1998-02-22
# 51      Pruitt, Randy     Main  Facilities/Engineering  Contract 2006-03-16
# ..                ...      ...                     ...       ...        ...
# 707     Graham, David    North         Quality Control  Contract 2011-09-14
# 712  Jimenez, Dominic   Watson         Quality Control  Contract 2001-09-07
# 720     Martin, Terry     West         Quality Control  Contract 2008-10-07
# 721       Craig, Alan     Main         Quality Control  Contract 2008-11-16
# 742  Bradshaw, Sheryl    North    Research/Development  Contract 2008-07-10
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ## Sort the number of column you want. eg head (20 )

# %%
my_copy[  (five | three) & (Ft | Contract)  ].sort_values('Salary', ascending = False).head(20)
# Out:
# 3           Employee Name Building              Department    Status  \
# 284      Huffman, Ignacio    North           Manufacturing  Contract
# 75           Stone, Brian    North  Facilities/Engineering  Contract
# 306       Trujillo, Shawn    North           Manufacturing  Contract
# 68       Wallace, Timothy   Watson  Facilities/Engineering  Contract
# 720         Martin, Terry     West         Quality Control  Contract
# 47          Briggs, Bryan     Main  Facilities/Engineering  Contract
# 81            James, Lynn     West  Facilities/Engineering  Contract
# 381            Bush, Rena    South               Marketing  Contract
# 177  Padilla, Christopher     Main     Product Development  Contract
# 654       Erickson, Ricky    North         Quality Control  Contract
# 332    Camacho, Stephanie   Watson           Manufacturing  Contract
# 70       Morgan, Patricia    North  Facilities/Engineering  Contract
# 405           Lucas, John    North                   Sales  Contract
# ...

# %% [markdown]
# ## ANALYZING

# %%
"""
Questions for Data Filtering Assignment in Python 

•	Filter and display all employees with more than 15 years of experience, and sort them by Years in descending order.
	•	Filter all Full-Time employees in the IT department, and sort them by Salary in ascending order.
	•	Display the top 5 highest-paid Contract employees by sorting them in descending order of New Salary.
	•	Filter employees who work in the North building and have a Job Rating of 5, then sort them by New Salary in descending order.
	•	Find all employees with missing or blank values in the Benefits column, and sort them by Employee Name alphabetically.
 """
# Out:
# '\nQuestions for Data Filtering Assignment in Python \n\n•\tFilter and display all employees with more than 15 years of experience, and sort them by Years in descending order.\n\t•\tFilter all Full-Time employees in the IT department, and sort them by Salary in ascending order.\n\t•\tDisplay the top 5 highest-paid Contract employees by sorting them in descending order of New Salary.\n\t•\tFilter employees who work in the North building and have a Job Rating of 5, then sort them by New Salary in descending order.\n\t•\tFind all employees with missing or blank values in the Benefits column, and sort them by Employee Name\xa0alphabetically.\n '

# %% [markdown]
# ## Employment moore than 15 years of experience, sort by years in descending order

# %%
my_copy ['Years'] > 15
my_copy[my_copy ['Years'] > 15].sort_values('Years',ascending = False)
# Out:
# 3         Employee Name Building              Department     Status  \
# 528      Andrews, Diane    North      Account Management     Hourly
# 509       Booth, Raquel     West      Account Management     Hourly
# 191       Tate, Zachary     Taft           Manufacturing        F T
# 517       Jackson, Eric    North      Account Management        F T
# 521      Preston, Chris     Main      Account Management        F T
# ..                  ...      ...                     ...        ...
# 604        Rush, Lateef     West       Quality Assurance  Half-Time
# 605      Munoz, Michael    South       Quality Assurance        F T
# 612  Glenn, Christopher    South       Quality Assurance  Half-Time
# 72          Hood, Renee    North  Facilities/Engineering        F T
# 303        Weaver, Eric    North           Manufacturing        F T
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary
# 528 1998-08-21     21  No Benefits   16688           3       16688
# ...

# %% [markdown]
# ## Filter all Full-Time employees in the IT department, and sort them by Salary in ascending order.

# %%
ft = my_copy['Status'] == 'Full Time'
it = my_copy['Department'] == 'IT'

my_copy[ ft & it ]
# Out:
# Empty DataFrame
# Columns: [Employee Name, Building, Department, Status, Hire Date, Years, Benefits, Salary, Job Rating, New Salary]
# Index: []

# %%
my_copy[ (ft) & (it) ]
# Out:
# Empty DataFrame
# Columns: [Employee Name, Building, Department, Status, Hire Date, Years, Benefits, Salary, Job Rating, New Salary]
# Index: []

# %%
[ ft & it ]
# Out:
# [4      False
#  5      False
#  6      False
#  7      False
#  8      False
#         ...
#  740    False
#  741    False
#  742    False
#  743    False
#  744    False
#  Length: 741, dtype: bool]

# %% [markdown]
# #### Filter employees who work in the North building and have a Job Rating of 5, then sort them by New Salary in descending order.

# %%
my_copy['Building'] == 'North'
my_copy['Job Rating'] == 5
# Out:
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
#        ...
# 740    False
# 741    False
# 742     True
# 743    False
# 744    False
# Name: Job Rating, Length: 741, dtype: bool

# %%
n = my_copy['Building'] == 'North'
five = my_copy['Job Rating'] == 5

# %%
my_copy[ n & five ].sort_values('New Salary', ascending = False)
# Out:
# 3         Employee Name Building                   Department     Status  \
# 251     Burgess, Cherie    North                Manufacturing        F T
# 284    Huffman, Ignacio    North                Manufacturing   Contract
# 75         Stone, Brian    North       Facilities/Engineering   Contract
# 306     Trujillo, Shawn    North                Manufacturing   Contract
# 184    Douglas, Kenneth    North           Major Mfg Projects     Hourly
# 719      Marsh, Cynthia    North              Quality Control        F T
# 17       Wilkins, Jesse    North                     Training        F T
# 70     Morgan, Patricia    North       Facilities/Engineering   Contract
# 63   Whitehead, Carolyn    North       Facilities/Engineering        F T
# 322      Coleman, Roque    North                Manufacturing        F T
# 261   Bradford, Raymond    North                Manufacturing   Contract
# 49      McDonald, Debra    North       Facilities/Engineering        F T
# ...

# %% [markdown]
# ## 5 highest-paid Contract employees by sorting them in descending order of New Salary.

# %%
my_copy['Status'] == 'Contract'
# Out:
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
#        ...
# 740     True
# 741    False
# 742     True
# 743    False
# 744    False
# Name: Status, Length: 741, dtype: bool

# %%
con = my_copy['Status'] == 'Contract'

# %% [markdown]
# ## Find all employees with missing or blank values in the Benefits column, and sort them by Employee Name alphabetically.

# %% [markdown]
# ### youu can use .head() or [:5] to get five columns

# %%
my_copy[ con ].sort_values('New Salary', ascending = False).head() 
my_copy[ con ].sort_values('New Salary', ascending = False) [:5 ]
# Out:
# 3       Employee Name Building              Department    Status  Hire Date  \
# 541     Cameron, John    North      Account Management  Contract 2000-09-18
# 284  Huffman, Ignacio    North           Manufacturing  Contract 2000-07-11
# 579   Alvarez, Steven     Taft       Quality Assurance  Contract 2011-02-13
# 75       Stone, Brian    North  Facilities/Engineering  Contract 2010-07-09
# 306   Trujillo, Shawn    North           Manufacturing  Contract 2010-09-28
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# 541     19  No Benefits   89640           4       89640
# 284     19  No Benefits   89520           5       89520
# 579      8  No Benefits   89450           2       89450
# 75       9  No Benefits   89310           5       89310
# 306      9  No Benefits   88840           5       88840

# %%
my_copy[ 'Benefits'] == 'No Benefits'
my_copy[my_copy[ 'Benefits'] == 'No Benefits']
# Out:
# 3         Employee Name Building            Department    Status  Hire Date  \
# 6      Dawson, Jonathan     West                   ADC  Contract 2007-03-06
# 7          Duran, Brian     Taft                   ADC    Hourly 2012-08-30
# 11        Spencer, Boyd     Main              Training  Contract 2007-04-17
# 20            Rowe, Ken     West              Training  Contract 2000-09-08
# 23   Gallagher, Johnson     West              Training    Hourly 2009-11-09
# ..                  ...      ...                   ...       ...        ...
# 737       Dalton, Carol     West       Research Center  Contract 2011-05-29
# 738   Patterson, Robert     Main       Research Center  Contract 2011-06-25
# 740         Olsen, Ewan    North  Research/Development  Contract 2007-02-03
# 742    Bradshaw, Sheryl    North  Research/Development  Contract 2008-07-10
# 744      Flynn, Melissa   Watson  Research/Development    Hourly 2010-12-31
#
# 3    Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ## sorting by Employee

# %%
my_copy[ 'Benefits'] == 'No Benefits'
my_copy[my_copy[ 'Benefits'] == 'No Benefits'].sort_values('Employee Name')
# Out:
# 3         Employee Name Building                   Department    Status  \
# 341  Alexander, Charles     West          Manufacturing Admin  Contract
# 579     Alvarez, Steven     Taft            Quality Assurance  Contract
# 529    Anderson, Teason   Watson           Account Management  Contract
# 528      Andrews, Diane    North           Account Management    Hourly
# 645    Armstrong, David    North              Quality Control  Contract
# ..                  ...      ...                          ...       ...
# 466     Williams, Scott     Taft  Professional Training Group  Contract
# 256   Williamson, Sumed     Main                Manufacturing  Contract
# 166           Wise, Ted    North          Product Development  Contract
# 148       Woodward, Tim     Main          Product Development  Contract
# 88         York, Steven    North       Facilities/Engineering  Contract
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary
# ...

# %% [markdown]
# ## VISUALIZATION

# %% [markdown]
# ## Group by

# %%
data.groupby('Status')['Salary'].sum()
# Out:
# Status
# Contract     11422547
# F T          22052615
# Half-Time     2984325
# Hourly        1407620
# Name: Salary, dtype: int32

# %%
data.groupby('Status', as_index=False)['Salary'].sum()
# Out:
#       Status    Salary
# 0   Contract  11422547
# 1        F T  22052615
# 2  Half-Time   2984325
# 3     Hourly   1407620

# %% [markdown]
# ## avg years  of experience of employee in each deprtment

# %%
data.groupby('Department')['Years'].mean()
# Out:
# Department
# ADC                            12.000000
# Account Management             13.386364
# Creative                       14.473684
# Environmental Compliance       13.071429
# Environmental Health/Safety    13.000000
# Facilities/Engineering         13.355932
# Green Building                 11.625000
# Human Resources                12.222222
# IT                             11.931818
# Major Mfg Projects             14.625000
# Manufacturing                  14.450331
# Manufacturing Admin            12.857143
# Marketing                      14.098039
# Product Development            12.526316
# Professional Training Group     9.125000
# Quality Assurance              14.315068
# Quality Control                12.776596
# Research Center                13.600000
# Research/Development           12.200000
# Sales                          13.809524
# Training                       14.352941
# Name: Years, dtype: float64

# %%
data.groupby('Department')['Years'].mean()
data.groupby('Department',as_index=False)['Years'].mean()
# Out:
#                      Department      Years
# 0                           ADC  12.000000
# 1            Account Management  13.386364
# 2                      Creative  14.473684
# 3      Environmental Compliance  13.071429
# 4   Environmental Health/Safety  13.000000
# 5        Facilities/Engineering  13.355932
# 6                Green Building  11.625000
# 7               Human Resources  12.222222
# 8                            IT  11.931818
# 9            Major Mfg Projects  14.625000
# 10                Manufacturing  14.450331
# 11          Manufacturing Admin  12.857143
# 12                    Marketing  14.098039
# 13          Product Development  12.526316
# 14  Professional Training Group   9.125000
# 15            Quality Assurance  14.315068
# 16              Quality Control  12.776596
# 17              Research Center  13.600000
# 18         Research/Development  12.200000
# 19                        Sales  13.809524
# 20                     Training  14.352941

# %% [markdown]
# ## NUMBER of staff n te bulding

# %%
data.groupby('Building')['Employee Name'].count()
# Out:
# Building
# Main      199
# North     221
# South      70
# Taft       63
# Watson     62
# West      126
# Name: Employee Name, dtype: int64

# %%
data.groupby('Building', as_index = False)['Employee Name'].count()
# Out:
#   Building  Employee Name
# 0     Main            199
# 1    North            221
# 2    South             70
# 3     Taft             63
# 4   Watson             62
# 5     West            126

# %%
data.groupby(  ['Building']  )['Salary'].sum()
# Out:
# Building
# Main      10286258
# North     11568566
# South      3410365
# Taft       3463700
# Watson     3032894
# West       6105324
# Name: Salary, dtype: int32

# %%
 data.groupby(  ['Building', 'Status'], as_index = False )['Salary'].sum()
# Out:
#    Building     Status   Salary
# 0      Main   Contract  2835149
# 1      Main        F T  6225750
# 2      Main  Half-Time   789155
# 3      Main     Hourly   436204
# 4     North   Contract  3016714
# 5     North        F T  7359169
# 6     North  Half-Time   770965
# 7     North     Hourly   421718
# 8     South   Contract  1164480
# 9     South        F T  1712870
# 10    South  Half-Time   374805
# 11    South     Hourly   158210
# 12     Taft   Contract  1348840
# 13     Taft        F T  1777250
# 14     Taft  Half-Time   301930
# 15     Taft     Hourly    35680
# 16   Watson   Contract   911746
# 17   Watson        F T  1816288
# 18   Watson  Half-Time   192420
# 19   Watson     Hourly   112440
# 20     West   Contract  2145618
# 21     West        F T  3161288
# 22     West  Half-Time   555050
# 23     West     Hourly   243368

# %%
data.groupby('Building')['Salary'].agg(['sum','mean','max','min','count'])
# Out:
#                sum          mean    max    min  count
# Building
# Main      10286258  51689.738693  89780   9180    199
# North     11568566  52346.452489  89740   8892    221
# South      3410365  48719.500000  88820  15910     70
# Taft       3463700  54979.365079  89450  13435     63
# Watson     3032894  48917.645161  88000  10572     62
# West       6105324  48454.952381  86830  10636    126

# %%
data.groupby( ['Building', 'Status']) ['Salary'].agg(['sum','mean','max','min','count'])
# Out:
#                         sum          mean    max    min  count
# Building Status
# Main     Contract   2835149  56702.980000  86100  21580     50
#          F T        6225750  57116.972477  89140  22920    109
#          Half-Time   789155  32881.458333  89780  12545     24
#          Hourly      436204  27262.750000  61860   9180     16
# North    Contract   3016714  59151.254902  89640  22320     51
#          F T        7359169  57493.507812  89740  22410    128
#          Half-Time   770965  28554.259259  51800  10520     27
#          Hourly      421718  28114.533333  85130   8892     15
# South    Contract   1164480  52930.909091  87830  25130     22
#          F T        1712870  51905.151515  88820  22820     33
#          Half-Time   374805  37480.500000  49405  15910     10
#          Hourly      158210  31642.000000  38768  22344      5
# Taft     Contract   1348840  61310.909091  89450  31270     22
#          F T        1777250  57330.645161  82400  22900     31
# ...

# %% [markdown]
# ## calculate number of staffs in the building ,Department and Status
# ##  total, avg, highest, lowest  number of status

# %%
data.groupby(  [ 'Building','Status','Department',], as_index = False)['Employee Name'].count()
# Out:
#     Building    Status              Department  Employee Name
# 0       Main  Contract      Account Management              9
# 1       Main  Contract                Creative              2
# 2       Main  Contract  Facilities/Engineering              4
# 3       Main  Contract          Green Building              1
# 4       Main  Contract         Human Resources              1
# ..       ...       ...                     ...            ...
# 244     West    Hourly                      IT              1
# 245     West    Hourly           Manufacturing              3
# 246     West    Hourly       Quality Assurance              2
# 247     West    Hourly         Quality Control              1
# 248     West    Hourly                Training              1
#
# [249 rows x 4 columns]

# %%
data.groupby('Status') ['Salary'].agg(['sum','mean','max','min','count'])
# Out:
#                 sum          mean    max    min  count
# Status
# Contract   11422547  57689.631313  89640  21580    198
# F T        22052615  56113.524173  89740  22410    393
# Half-Time   2984325  31086.718750  89780  10520     96
# Hourly      1407620  26067.037037  85130   8892     54

# %% [markdown]
# ## matplotlib

# %%
data.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary
# 4          DMR   54550           1       55864
# 5           DM   26795           4       26795
# 6  No Benefits   42540           5       42540
# 7  No Benefits   35680           2       35680
# 8            M   72830           2       72830

# %% [markdown]
# ## total salary paid for each building Using bar chart

# %%
BIG = data.groupby('Building', as_index=False)['Salary'].sum()

# %%
BIG
# Out:
#   Building    Salary
# 0     Main  10286258
# 1    North  11568566
# 2    South   3410365
# 3     Taft   3463700
# 4   Watson   3032894
# 5     West   6105324

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(BIG['Building'],BIG['Salary'])
plt.title('Tatal salary for Building')
plt.xlabel('<-- Building-->')
plt.ylabel('<-- Salary-->')
plt.savefig('building salary.jpg')
plt.savefig('building salary.pdf')

plt.show()

# %% [markdown]
# ## Number of staffs in Differnce status Using pie chart

# %%
data.groupby('Status', as_index=False)['Employee Name'].count()
# Out:
#       Status  Employee Name
# 0   Contract            198
# 1        F T            393
# 2  Half-Time             96
# 3     Hourly             54

# %%
sta = data.groupby('Status', as_index=False)['Employee Name'].count()

# %%
sta
# Out:
#       Status  Employee Name
# 0   Contract            198
# 1        F T            393
# 2  Half-Time             96
# 3     Hourly             54

# %%
plt.pie(sta['Employee Name'],labels = sta['Status'])

plt.show()

# %% [markdown]
# ## Spliting Columns

# %%
data['Employee Name'].str.split(',')
# Out:
# 4                [Othello]
# 5        [Taylor,  Hector]
# 6      [Dawson,  Jonathan]
# 7          [Duran,  Brian]
# 8          [Weber,  Larry]
#               ...
# 740         [Olsen,  Ewan]
# 741          [Green,  Kim]
# 742    [Bradshaw,  Sheryl]
# 743        [Riley,  David]
# 744      [Flynn,  Melissa]
# Name: Employee Name, Length: 741, dtype: object

# %%
data['Employee Name'].str.split(',')
# Out:
# 4                [Othello]
# 5        [Taylor,  Hector]
# 6      [Dawson,  Jonathan]
# 7          [Duran,  Brian]
# 8          [Weber,  Larry]
#               ...
# 740         [Olsen,  Ewan]
# 741          [Green,  Kim]
# 742    [Bradshaw,  Sheryl]
# 743        [Riley,  David]
# 744      [Flynn,  Melissa]
# Name: Employee Name, Length: 741, dtype: object

# %%
data['Employee Name'].str.split(',',expand=True)
# Out:
#             0          1
# 4     Othello       None
# 5      Taylor     Hector
# 6      Dawson   Jonathan
# 7       Duran      Brian
# 8       Weber      Larry
# ..        ...        ...
# 740     Olsen       Ewan
# 741     Green        Kim
# 742  Bradshaw     Sheryl
# 743     Riley      David
# 744     Flynn    Melissa
#
# [741 rows x 2 columns]

# %% [markdown]
# ## add new columns

# %%
data[['First Name','Last Name']] = data['Employee Name'].str.split(',',expand=True)

# %%
data.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary First Name  Last Name
# 4          DMR   54550           1       55864    Othello       None
# 5           DM   26795           4       26795     Taylor     Hector
# 6  No Benefits   42540           5       42540     Dawson   Jonathan
# 7  No Benefits   35680           2       35680      Duran      Brian
# 8            M   72830           2       72830      Weber      Larry

# %%
data
# Out:
# 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC        F T 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC        F T 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development        F T 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of 3       Employee Name Building            Department     Status  Hire Date  \
# 4             Othello     West                   ADC        F T 1999-01-11
# 5      Taylor, Hector     West                   ADC  Half-Time 2011-02-21
# 6    Dawson, Jonathan     West                   ADC   Contract 2007-03-06
# 7        Duran, Brian     Taft                   ADC     Hourly 2012-08-30
# 8        Weber, Larry   Watson                   ADC        F T 2007-12-31
# ..                ...      ...                   ...        ...        ...
# 740       Olsen, Ewan    North  Research/Development   Contract 2007-02-03
# 741        Green, Kim   Watson  Research/Development  Half-Time 2000-02-01
# 742  Bradshaw, Sheryl    North  Research/Development   Contract 2008-07-10
# 743      Riley, David     Taft  Research/Development        F T 2010-07-25
# 744    Flynn, Melissa   Watson  Research/Development     Hourly 2010-12-31
#
# ...

# %% [markdown]
# ## Extractig Month, Days, Year, from my Hire Date ( Calendar)

# %% [markdown]
# ## Years

# %%
data['Hire Date'].dt.year
# Out:
# 4      1999
# 5      2011
# 6      2007
# 7      2012
# 8      2007
#        ...
# 740    2007
# 741    2000
# 742    2008
# 743    2010
# 744    2010
# Name: Hire Date, Length: 741, dtype: int32

# %%
data['Year'] = data['Hire Date'].dt.year

# %%
data['Hire Date'].dt.year
data['Year'] = data['Hire Date'].dt.year
data.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary First Name  Last Name  Year
# 4          DMR   54550           1       55864    Othello       None  1999
# 5           DM   26795           4       26795     Taylor     Hector  2011
# 6  No Benefits   42540           5       42540     Dawson   Jonathan  2007
# 7  No Benefits   35680           2       35680      Duran      Brian  2012
# 8            M   72830           2       72830      Weber      Larry  2007

# %% [markdown]
# ## month

# %% [markdown]
# ## Extract month

# %%
data['Hire Date'].dt.month_name()
# Out:
# 4       January
# 5      February
# 6         March
# 7        August
# 8      December
#          ...
# 740    February
# 741    February
# 742        July
# 743        July
# 744    December
# Name: Hire Date, Length: 741, dtype: object

# %%
data['Hire Date'].dt.month_name()
data['Month_Name'] = data['Hire Date'].dt.month_name()
data.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary First Name  Last Name  Year  \
# 4          DMR   54550           1       55864    Othello       None  1999
# 5           DM   26795           4       26795     Taylor     Hector  2011
# 6  No Benefits   42540           5       42540     Dawson   Jonathan  2007
# 7  No Benefits   35680           2       35680      Duran      Brian  2012
# 8            M   72830           2       72830      Weber      Larry  2007
#
# 3 Month_Name
# 4    January
# 5   February
# 6      March
# 7     August
# 8   December

# %%
data['Hire Date'].dt.month
# Out:
# 4       1
# 5       2
# 6       3
# 7       8
# 8      12
#        ..
# 740     2
# 741     2
# 742     7
# 743     7
# 744    12
# Name: Hire Date, Length: 741, dtype: int32

# %%
data['Hire Date'].dt.month
data['Month Index'] = data['Hire Date'].dt.month
data.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary First Name  Last Name  Year  \
# 4          DMR   54550           1       55864    Othello       None  1999
# 5           DM   26795           4       26795     Taylor     Hector  2011
# 6  No Benefits   42540           5       42540     Dawson   Jonathan  2007
# 7  No Benefits   35680           2       35680      Duran      Brian  2012
# 8            M   72830           2       72830      Weber      Larry  2007
#
# 3 Month_Name  Month Index
# 4    January            1
# 5   February            2
# ...

# %%
data['Hire Date'].dt.month
data['Month Index'] = data['Hire Date'].dt.month
data.head()
data.sort_values('Month Index')
# Out:
# 3           Employee Name Building            Department     Status  \
# 4                 Othello     West                   ADC        F T
# 198        Dixon, Richard     West         Manufacturing        F T
# 197          Vincent, Guy    North         Manufacturing        F T
# 196          Conley, Mark    South         Manufacturing        F T
# 195      Rodriguez, Scott    North         Manufacturing   Contract
# ..                    ...      ...                   ...        ...
# 636          Holt, Robert    North     Quality Assurance        F T
# 177  Padilla, Christopher     Main   Product Development   Contract
# 185       Campos, Richard     Main    Major Mfg Projects     Hourly
# 567             Cabe, Max     Main    Account Management  Half-Time
# 744        Flynn, Melissa   Watson  Research/Development     Hourly
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary First Name  \
# ...

# %% [markdown]
# ## Extract Days

# %%
data['Hire Date'].dt.day_name()
# Out:
# 4        Monday
# 5        Monday
# 6       Tuesday
# 7      Thursday
# 8        Monday
#          ...
# 740    Saturday
# 741     Tuesday
# 742    Thursday
# 743      Sunday
# 744      Friday
# Name: Hire Date, Length: 741, dtype: object

# %%
data['Days'] = data['Hire Date'].dt.day_name()
data.head(2)
# Out:
# 3   Employee Name Building Department     Status  Hire Date  Years Benefits  \
# 4         Othello     West        ADC        F T 1999-01-11     20      DMR
# 5  Taylor, Hector     West        ADC  Half-Time 2011-02-21      8       DM
#
# 3  Salary  Job Rating  New Salary First Name Last Name  Year Month_Name  \
# 4   54550           1       55864    Othello      None  1999    January
# 5   26795           4       26795     Taylor    Hector  2011   February
#
# 3  Month Index  Day Index    Days
# 4            1          0  Monday
# 5            2          0  Monday

# %% [markdown]
# ## Extract Weekdays

# %%
data['Hire Date'].dt.day
# Out:
# 4      11
# 5      21
# 6       6
# 7      30
# 8      31
#        ..
# 740     3
# 741     1
# 742    10
# 743    25
# 744    31
# Name: Hire Date, Length: 741, dtype: int32

# %%
data['Hire Date'].dt.day
data['Day Index'] = data['Hire Date'].dt.weekday
data.head()
# Out:
# 3     Employee Name Building Department     Status  Hire Date  Years  \
# 4           Othello     West        ADC        F T 1999-01-11     20
# 5    Taylor, Hector     West        ADC  Half-Time 2011-02-21      8
# 6  Dawson, Jonathan     West        ADC   Contract 2007-03-06     14
# 7      Duran, Brian     Taft        ADC     Hourly 2012-08-30      7
# 8      Weber, Larry   Watson        ADC        F T 2007-12-31     11
#
# 3     Benefits  Salary  Job Rating  New Salary First Name  Last Name  Year  \
# 4          DMR   54550           1       55864    Othello       None  1999
# 5           DM   26795           4       26795     Taylor     Hector  2011
# 6  No Benefits   42540           5       42540     Dawson   Jonathan  2007
# 7  No Benefits   35680           2       35680      Duran      Brian  2012
# 8            M   72830           2       72830      Weber      Larry  2007
#
# 3 Month_Name  Month Index  Day Index      Days
# 4    January            1          0    Monday
# ...

# %%
data[data['Benefits'] == 'No Benefits'].sort_values('Employee Name')
# Out:
# 3         Employee Name Building                   Department    Status  \
# 341  Alexander, Charles     West          Manufacturing Admin  Contract
# 579     Alvarez, Steven     Taft            Quality Assurance  Contract
# 529    Anderson, Teason   Watson           Account Management  Contract
# 528      Andrews, Diane    North           Account Management    Hourly
# 645    Armstrong, David    North              Quality Control  Contract
# ..                  ...      ...                          ...       ...
# 466     Williams, Scott     Taft  Professional Training Group  Contract
# 256   Williamson, Sumed     Main                Manufacturing  Contract
# 166           Wise, Ted    North          Product Development  Contract
# 148       Woodward, Tim     Main          Product Development  Contract
# 88         York, Steven    North       Facilities/Engineering  Contract
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary  \
# ...

# %%
data['Building'] == 'North'
data['Job Rating'] == 5
data[(data['Building'] == 'North') | (data['Job Rating'] == 5)].sort_values('New Salary',ascending = False)
# Out:
# 3         Employee Name Building                   Department     Status  \
# 251     Burgess, Cherie    North                Manufacturing        F T
# 541       Cameron, John    North           Account Management   Contract
# 284    Huffman, Ignacio    North                Manufacturing   Contract
# 75         Stone, Brian    North       Facilities/Engineering   Contract
# 424      Hancock, Allen    North                           IT        F T
# ..                  ...      ...                          ...        ...
# 680    Ellison, Melyssa    North              Quality Control  Half-Time
# 283        Moran, Carol    North                Manufacturing  Half-Time
# 109       Carey, Andrea    North  Environmental Health/Safety  Half-Time
# 278       Atkins, Kevin    North                Manufacturing     Hourly
# 237  Dickerson, Lincoln    North                Manufacturing     Hourly
#
# 3    Hire Date  Years     Benefits  Salary  Job Rating  New Salary First Name  \
# ...

# %% [markdown]
# ## Monthly Salary paid to Employee

# %%
data.groupby( ['Month_Name','Month Index'],as_index=False)['Salary'].sum()
# Out:
#    Month_Name  Month Index   Salary
# 0       April            4  3315019
# 1      August            8  2922947
# 2    December           12  2645054
# 3    February            2  3087746
# 4     January            1  3737542
# 5        July            7  3502888
# 6        June            6  2952570
# 7       March            3  3708939
# 8         May            5  2767661
# 9    November           11  2933189
# 10    October           10  3289420
# 11  September            9  3004132

# %%
data.groupby( ['Month_Name','Month Index'],as_index=False)['Salary'].sum().sort_values('Month Index')
# Out:
#    Month_Name  Month Index   Salary
# 4     January            1  3737542
# 3    February            2  3087746
# 7       March            3  3708939
# 0       April            4  3315019
# 8         May            5  2767661
# 6        June            6  2952570
# 5        July            7  3502888
# 1      August            8  2922947
# 11  September            9  3004132
# 10    October           10  3289420
# 9    November           11  2933189
# 2    December           12  2645054

# %% [markdown]
# ## display monthly salary paid to employee

# %%
mon_sal = data.groupby( ['Month_Name','Month Index'],as_index=False)['Salary'].sum().sort_values('Month Index')

# %%
plt.plot(mon_sal ['Month_Name'], mon_sal['Salary'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.plot(mon_sal ['Month_Name'], mon_sal['Salary'])
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(mon_sal ['Month_Name'], mon_sal['Salary'])
plt.xticks(rotation=45)
plt.show()

# %%
mon_sal = data.groupby( ['Month_Name','Month Index'],as_index=False)['Salary'].sum().sort_values('Month Index')

# %%
plt.plot(mon_sal ['Month_Name'], mon_sal['Salary'])
plt.title('Monthly Salary')
plt.xlabel('Months')
plt.ylabel('Salary')

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## To get Pivot Table

# %% [markdown]
# ## Pivot Table

# %% [markdown]
# #### Number of salary paid in different  days

# %%
pd.pivot_table(data=data,values='Salary',index='Days',columns='Month_Name',aggfunc='sum')
# Out:
# Month_Name   April  August  December  February  January    July    June  \
# Days
# Friday      520180  441259    234792    677669   760424  806224  786644
# Monday      582380  261260    533385    268930   552111  400733  423260
# Saturday    449992  627890    403352    398680   715453  280090  551128
# Sunday      377334  294902    312720    535575   391780  490936  171127
# Thursday    392815  245596    236445    182620   149330  580652  153215
# Tuesday     635518  593970    688140    643868   827181  673650  715826
# Wednesday   356800  458070    236220    380404   341263  270603  151370
#
# Month_Name   March     May  November  October  September
# Days
# Friday      742445  503348    574222   518018     755868
# Monday      415528  329070    272496   509861     296858
# Saturday    590120  481479    123560   506345     429340
# Sunday      228142  380665    587115   367484     309154
# Thursday    284031  129560    260142   150700     171400
# ...

# %%
#### Number of employees in diffrent department days

# %%
pd.pivot_table(data=data,values='Employee Name',index = 'Status',columns = 'Department',aggfunc = 'count')
# Out:
# Department  ADC  Account Management  Creative  Environmental Compliance  \
# Status
# Contract    1.0                24.0       7.0                       1.0
# F T         2.0                47.0       8.0                       9.0
# Half-Time   1.0                13.0       2.0                       3.0
# Hourly      1.0                 4.0       2.0                       1.0
#
# Department  Environmental Health/Safety  Facilities/Engineering  \
# Status
# Contract                            NaN                    19.0
# F T                                 6.0                    29.0
# Half-Time                           2.0                     7.0
# Hourly                              1.0                     4.0
#
# Department  Green Building  Human Resources    IT  Major Mfg Projects  ...  \
# Status                                                                 ...
# Contract               3.0              4.0   7.0                 2.0  ...
# ...

# %%
data.head(2)
# Out:
# 3   Employee Name Building Department     Status  Hire Date  Years Benefits  \
# 4         Othello     West        ADC        F T 1999-01-11     20      DMR
# 5  Taylor, Hector     West        ADC  Half-Time 2011-02-21      8       DM
#
# 3  Salary  Job Rating  New Salary First Name Last Name  Year Month_Name  \
# 4   54550           1       55864    Othello      None  1999    January
# 5   26795           4       26795     Taylor    Hector  2011   February
#
# 3  Month Index  Day Index    Days
# 4            1          0  Monday
# 5            2          0  Monday

# %%
pd.pivot_table(data=data,values='Employee Name', index = 'Benefits',columns = 'Building',aggfunc = 'count')
# Out:
# Building     Main  North  South  Taft  Watson  West
# Benefits
# D            16.0   19.0    8.0   5.0     3.0  11.0
# DM           12.0   26.0    4.0   4.0     3.0  16.0
# DMR          49.0   54.0   18.0  17.0    10.0  21.0
# DR            NaN    1.0    NaN   NaN     NaN   NaN
# M            22.0   17.0    3.0   3.0     9.0   8.0
# No Benefits  65.0   65.0   25.0  22.0    22.0  48.0
# R            35.0   39.0   12.0  12.0    15.0  22.0

# %% [markdown]
# ## Seaborn

# %%
# matplotlib
# seaborn
# plotlt

# %%
import seaborn as sns

# %%
bebefits_package = pd.pivot_table(data=data,values='Employee Name', index = 'Benefits',columns = 'Building',aggfunc = 'count')

# %%
sns.heatmap(bebefits_package)
# Out:
# <Axes: xlabel='Building', ylabel='Benefits'>
